# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

import datetime as dt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 100)

from etl import quarter_to_dt

# %% [markdown]
# ## Methodology:
#
# I will clean and transform each dataframe separated by question, so for the first question I will verify and make the transformations needed in the related dataframes, and the same for the remaining questions.

# %% [markdown]
# **Question 1.** Which economic sectors have experienced the highest growth since 2010, and how did the COVID-19 pandemic shift their trajectories?
# **Related dataframes**: QLF03, QLF05, QLF07, QLF32, QES01, QES03

# %%
# quick visualization of each df
q1_related = ['QLF03', 
              'QLF05', 
              'QLF07']
# deleted from the related QES01, QES03, QLF32 because of the lack of info compared to the others
# will delete QLF05, QLF07 because of the inconsistency of what makes an "adult"
# checked if the total (all region, sex and sector) for QLF03 and QLF05 + QLF07, and returned different numbers (27.1 difference)
# decided to go with QLF03, cause it provide the exact data that I need

for df in q1_related:
    df_v = pd.read_csv(f'../data/raw/{df}.csv')

    print(f'{df} Dataframe')
    display(df_v.head())
    display(df_v.tail())
    print('-------------------')
# Out:
# QLF03 Dataframe
#                                 Statistic Quarter         Sex  \
# 0  Persons aged 15-89 years in Employment  1998Q1  Both sexes
# 1  Persons aged 15-89 years in Employment  1998Q1  Both sexes
# 2  Persons aged 15-89 years in Employment  1998Q1  Both sexes
# 3  Persons aged 15-89 years in Employment  1998Q1  Both sexes
# 4  Persons aged 15-89 years in Employment  1998Q1  Both sexes
#
#                           NACE Rev 2 Economic Sector   value
# 0                          All NACE economic sectors  1550.3
# 1              Agriculture, forestry and fishing (A)   135.6
# 2                                   Construction (F)   103.7
# 3  Wholesale and retail trade, repair of motor ve...   219.5
# 4                     Transportation and storage (H)    65.6
#                                                Statistic Quarter     Sex  \
# 11767  Persons aged 15-89 years in Employment (Season...  2025Q1  Female
# 11768  Persons aged 15-89 years in Employment (Season...  2025Q1  Female
# 11769  Persons aged 15-89 years in Employment (Season...  2025Q1  Female
# 11770  Persons aged 15-89 years in Employment (Season...  2025Q1  Female
# 11771  Persons aged 15-89 years in Employment (Season...  2025Q1  Female
#
#                               NACE Rev 2 Economic Sector  value
# 11767                 Industry and Construction (B to F)    NaN
# 11768                                  Services (G to U)    NaN
# 11769  Financial, insurance and real estate activitie...   72.4
# 11770                     Other NACE activities (R to U)   71.8
# 11771                                         Not stated    NaN
# -------------------
# QLF05 Dataframe
#                                       Statistic         Sex  \
# 0  Person aged 15 years and over in Employment   Both sexes
# 1  Person aged 15 years and over in Employment   Both sexes
# 2  Person aged 15 years and over in Employment   Both sexes
# 3  Person aged 15 years and over in Employment   Both sexes
# 4  Person aged 15 years and over in Employment   Both sexes
#
#   NACE Rev 2 Economic Sector Region Quarter   value
# 0  All NACE economic sectors  State  1998Q1  1550.4
# 1  All NACE economic sectors  State  1998Q2  1572.1
# 2  All NACE economic sectors  State  1998Q3  1636.3
# 3  All NACE economic sectors  State  1998Q4  1615.9
# 4  All NACE economic sectors  State  1999Q1  1644.5
#                                           Statistic     Sex  \
# 27211  Person aged 15 years and over in Employment   Female
# 27212  Person aged 15 years and over in Employment   Female
# 27213  Person aged 15 years and over in Employment   Female
# 27214  Person aged 15 years and over in Employment   Female
# 27215  Person aged 15 years and over in Employment   Female
#
#       NACE Rev 2 Economic Sector      Region Quarter  value
# 27211                 Not stated  South-West  2010Q4    NaN
# 27212                 Not stated  South-West  2011Q1    NaN
# 27213                 Not stated  South-West  2011Q2    NaN
# 27214                 Not stated  South-West  2011Q3    NaN
# 27215                 Not stated  South-West  2011Q4    NaN
# -------------------
# QLF07 Dataframe
#                                 STATISTIC Quarter         Sex  \
# 0  Persons aged 15-89 years in Employment  2012Q1  Both sexes
# 1  Persons aged 15-89 years in Employment  2012Q1  Both sexes
# 2  Persons aged 15-89 years in Employment  2012Q1  Both sexes
# 3  Persons aged 15-89 years in Employment  2012Q1  Both sexes
# 4  Persons aged 15-89 years in Employment  2012Q1  Both sexes
#
#   NACE Rev 2 Economic Sector      Region   value
# 0  All NACE economic sectors       State  1862.6
# 1  All NACE economic sectors      Border   145.1
# 2  All NACE economic sectors        West   175.8
# 3  All NACE economic sectors    Mid-West   188.8
# 4  All NACE economic sectors  South-East   153.3
#                                     STATISTIC Quarter     Sex  \
# 25753  Persons aged 15-89 years in Employment  2025Q1  Female
# 25754  Persons aged 15-89 years in Employment  2025Q1  Female
# 25755  Persons aged 15-89 years in Employment  2025Q1  Female
# 25756  Persons aged 15-89 years in Employment  2025Q1  Female
# 25757  Persons aged 15-89 years in Employment  2025Q1  Female
#
#       NACE Rev 2 Economic Sector      Region  value
# 25753                 Not stated  South-East    NaN
# 25754                 Not stated  South-West    NaN
# 25755                 Not stated      Dublin    NaN
# 25756                 Not stated    Mid-East    NaN
# 25757                 Not stated     Midland    NaN
# -------------------

# %%
# Transforming the Quarter column from string to datetime
df_qlf03 = pd.read_csv(f'../data/raw/QLF03.csv')
quarter_to_dt(df_qlf03)

# %% [markdown]
# **2. How has foreign workforce participation evolved in Ireland since the early 2000s?**

# %%
# quick visualization of each df
q2_related = ['QLF34', 'QLF35', 'QLF47', 'QLF48']

# can use all of those dataframes, being QLF34/QLF47 for explaining how much more people from outside work
# QLF35/QLF48 to show which sectors most employ foreigners

for df in q2_related:
    df_v = pd.read_csv(f'../data/raw/{df}.csv')

    print(f'{df} Dataframe')
    display(df_v.head())
    display(df_v.tail())
    print('-------------------')
# Out:
# QLF34 Dataframe
#                                       STATISTIC Quarter        Nationality  \
# 0  Persons aged 15 years and over in Employment  1998Q1  All nationalities
# 1  Persons aged 15 years and over in Employment  1998Q1  All nationalities
# 2  Persons aged 15 years and over in Employment  1998Q1  All nationalities
# 3  Persons aged 15 years and over in Employment  1998Q1  All nationalities
# 4  Persons aged 15 years and over in Employment  1998Q1  All nationalities
#
#                           NACE Rev 2 Economic Sector   value
# 0                          All NACE economic sectors  1550.3
# 1              Agriculture, forestry and fishing (A)   135.6
# 2                                   Construction (F)   103.7
# 3  Wholesale and retail trade; repair of motor ve...   219.5
# 4                     Transportation and storage (H)    65.6
#                                           STATISTIC Quarter  \
# 10299  Persons aged 15 years and over in Employment  2020Q4
# 10300  Persons aged 15 years and over in Employment  2020Q4
# 10301  Persons aged 15 years and over in Employment  2020Q4
# 10302  Persons aged 15 years and over in Employment  2020Q4
# 10303  Persons aged 15 years and over in Employment  2020Q4
#
#                    Nationality  \
# 10299  Other nationalities (7)
# 10300  Other nationalities (7)
# 10301  Other nationalities (7)
# 10302  Other nationalities (7)
# 10303  Other nationalities (7)
#
#                               NACE Rev 2 Economic Sector  value
# 10299        Human health and social work activities (Q)   21.7
# 10300                                  Industry (B to E)    NaN
# 10301  Financial, insurance and real estate activitie...    NaN
# 10302                     Other NACE activities (R to U)    NaN
# 10303                                         Not stated    NaN
# -------------------
# QLF35 Dataframe
#                         STATISTIC Quarter        Nationality  \
# 0  Persons aged 15 years and over  1998Q1  All nationalities
# 1  Persons aged 15 years and over  1998Q1  All nationalities
# 2  Persons aged 15 years and over  1998Q1  All nationalities
# 3  Persons aged 15 years and over  1998Q1  All nationalities
# 4  Persons aged 15 years and over  1998Q1  All nationalities
#
#        ILO Economic Status   value
# 0  All ILO economic status  2857.2
# 1          In labour force  1699.0
# 2            In employment  1550.3
# 3               Unemployed   148.7
# 4      Not in labour force  1158.2
#                            STATISTIC Quarter              Nationality  \
# 3215  Persons aged 15 years and over  2020Q4  Other nationalities (7)
# 3216  Persons aged 15 years and over  2020Q4  Other nationalities (7)
# 3217  Persons aged 15 years and over  2020Q4  Other nationalities (7)
# 3218  Persons aged 15 years and over  2020Q4  Other nationalities (7)
# 3219  Persons aged 15 years and over  2020Q4  Other nationalities (7)
#
#           ILO Economic Status  value
# 3215  All ILO economic status  196.2
# 3216          In labour force  133.7
# 3217            In employment  121.0
# 3218               Unemployed    NaN
# 3219      Not in labour force   62.5
# -------------------
# QLF47 Dataframe
#                                       Statistic Quarter  \
# 0  Persons aged 15 years and over in Employment  2021Q1
# 1  Persons aged 15 years and over in Employment  2021Q1
# 2  Persons aged 15 years and over in Employment  2021Q1
# 3  Persons aged 15 years and over in Employment  2021Q1
# 4  Persons aged 15 years and over in Employment  2021Q1
#
#   NACE Rev 2 Economic Sector  \
# 0  All NACE economic sectors
# 1  All NACE economic sectors
# 2  All NACE economic sectors
# 3  All NACE economic sectors
# 4  All NACE economic sectors
#
#                                          Citizenship   value
# 0                                      All Countries  2259.9
# 1  EU14 excl Irl (countries in the EU pre 2004 ex...    60.7
# 2  EU15 to EU27 (accession countries joined post ...   137.1
# 3                                     United Kingdom    46.4
# 4                                            Ireland  1898.0
#                                          Statistic Quarter  \
# 2137  Persons aged 15 years and over in Employment  2025Q1
# 2138  Persons aged 15 years and over in Employment  2025Q1
# 2139  Persons aged 15 years and over in Employment  2025Q1
# 2140  Persons aged 15 years and over in Employment  2025Q1
# 2141  Persons aged 15 years and over in Employment  2025Q1
#
#      NACE Rev 2 Economic Sector  \
# 2137                 Not stated
# 2138                 Not stated
# 2139                 Not stated
# 2140                 Not stated
# 2141                 Not stated
#
#                                             Citizenship  value
# 2137  EU15 to EU27 (accession countries joined post ...    NaN
# 2138                                     United Kingdom    NaN
# 2139                                            Ireland    NaN
# 2140                    All countries excluding Ireland    NaN
# 2141  All countries excluding Ireland,United Kingdom...    NaN
# -------------------
# QLF48 Dataframe
#                         Statistic Quarter      ILO Economic Status  \
# 0  Persons aged 15 years and over  2021Q1  All ILO economic status
# 1  Persons aged 15 years and over  2021Q1  All ILO economic status
# 2  Persons aged 15 years and over  2021Q1  All ILO economic status
# 3  Persons aged 15 years and over  2021Q1  All ILO economic status
# 4  Persons aged 15 years and over  2021Q1  All ILO economic status
#
#                                          Citizenship   value
# 0                                      All Countries  4056.3
# 1  EU14 excl Irl (countries in the EU pre 2004 ex...    80.9
# 2  EU15 to EU27 (accession countries joined post ...   207.1
# 3                                     United Kingdom    91.3
# 4                                            Ireland  3478.3
#                           Statistic Quarter  ILO Economic Status  \
# 590  Persons aged 15 years and over  2025Q1  Not in labour force
# 591  Persons aged 15 years and over  2025Q1  Not in labour force
# 592  Persons aged 15 years and over  2025Q1  Not in labour force
# 593  Persons aged 15 years and over  2025Q1  Not in labour force
# 594  Persons aged 15 years and over  2025Q1  Not in labour force
#
#                                            Citizenship   value
# 590  EU15 to EU27 (accession countries joined post ...    38.4
# 591                                     United Kingdom    34.1
# 592                                            Ireland  1358.5
# 593                    All countries excluding Ireland   157.9
# 594  All countries excluding Ireland,United Kingdom...    71.2
# -------------------

# %%
df_qlf34 = pd.read_csv(f'../data/raw/QLF34.csv')
quarter_to_dt(df_qlf34)

df_qlf35 = pd.read_csv(f'../data/raw/QLF35.csv')
quarter_to_dt(df_qlf35)

df_qlf47 = pd.read_csv(f'../data/raw/QLF47.csv')
quarter_to_dt(df_qlf47)

df_qlf48 = pd.read_csv(f'../data/raw/QLF48.csv')
quarter_to_dt(df_qlf48)

# %%
print('QLF34')
print(df_qlf34['Nationality'].value_counts())
print('------------------')
print('QLF35')
print(df_qlf35['Nationality'].value_counts())
print('------------------')
print('QLF47')
print(df_qlf47['Citizenship'].value_counts())
print('------------------')
print('QLF48')
print(df_qlf48['Citizenship'].value_counts())
# Out:
# QLF34
# Nationality
# All nationalities                                                      1472
# EU14 excl Irl (countries in the EU pre 2004 excluding UK & Ireland)    1472
# EU15 to EU27 (accession countries joined post 2004)                    1472
# UK                                                                     1472
# Irish                                                                  1472
# Non-Irish                                                              1472
# Other nationalities (7)                                                1472
# Name: count, dtype: int64
# ------------------
# QLF35
# Nationality
# All nationalities                                                      460
# EU14 excl Irl (countries in the EU pre 2004 excluding UK & Ireland)    460
# EU15 to EU27 (accession countries joined post 2004)                    460
# UK                                                                     460
# Irish                                                                  460
# Non-Irish                                                              460
# Other nationalities (7)                                                460
# Name: count, dtype: int64
# ------------------
# QLF47
# Citizenship
# All Countries                                                          306
# EU14 excl Irl (countries in the EU pre 2004 excluding UK & Ireland)    306
# EU15 to EU27 (accession countries joined post 2004)                    306
# United Kingdom                                                         306
# Ireland                                                                306
# All countries excluding Ireland                                        306
# All countries excluding Ireland,United Kingdom and EU272020            306
# Name: count, dtype: int64
# ------------------
# QLF48
# Citizenship
# All Countries                                                          85
# EU14 excl Irl (countries in the EU pre 2004 excluding UK & Ireland)    85
# EU15 to EU27 (accession countries joined post 2004)                    85
# United Kingdom                                                         85
# Ireland                                                                85
# All countries excluding Ireland                                        85
# All countries excluding Ireland,United Kingdom and EU272020            85
# Name: count, dtype: int64

# %%
print((df_qlf48.loc[(df_qlf48['Citizenship'] == 'Ireland') & (df_qlf48['ILO Economic Status'] == 'All ILO economic status'), 'value']).sum())
print((df_qlf48.loc[(df_qlf48['Citizenship'] == 'All countries excluding Ireland')  & (df_qlf48['ILO Economic Status'] == 'All ILO economic status'), 'value']).sum())
#print(df_qlf48.loc[df_qlf48['Citizenship'] == 'Other nationalities (7)', 'value'].sum())
print((df_qlf48.loc[(df_qlf48['Citizenship'] == 'All Countries') & (df_qlf48['ILO Economic Status'] == 'All ILO economic status'), 'value']).sum())
# Out:
# 60831.1
# 11309.9
# 72141.0

# %%
# dictionary for each nationality in QLF34 and QLF35, all of them being mutually exclusive
natio_dict = {'EU14 excl Irl (countries in the EU pre 2004 excluding UK & Ireland)': 'EU14',
              'EU15 to EU27 (accession countries joined post 2004)': 'EU15-27',
              'UK': 'UK',
              'Irish' : 'Irish',
              'Other nationalities (7)': 'Non-EU'}

# dictionary for each citizenship in QLF47 and QLF48
citi_dict = {'EU14 excl Irl (countries in the EU pre 2004 excluding UK & Ireland)': 'EU14',
             'EU15 to EU27 (accession countries joined post 2004)': 'EU15-27',
             'United Kingdom': 'UK',
             'Ireland' : 'Irish',
             'All countries excluding Ireland,United Kingdom and EU272020': 'Non-EU'}

# %%
df_qlf47.rename(columns={'Citizenship': 'Nationality'},
                         inplace=True)
df_qlf48.rename(columns={'Citizenship': 'Nationality'}, 
                         inplace=True)
df_qlf48
# Out:
#                           Statistic Quarter      ILO Economic Status  \
# 0    Persons aged 15 years and over  2021Q1  All ILO economic status
# 1    Persons aged 15 years and over  2021Q1  All ILO economic status
# 2    Persons aged 15 years and over  2021Q1  All ILO economic status
# 3    Persons aged 15 years and over  2021Q1  All ILO economic status
# 4    Persons aged 15 years and over  2021Q1  All ILO economic status
# ..                              ...     ...                      ...
# 590  Persons aged 15 years and over  2025Q1      Not in labour force
# 591  Persons aged 15 years and over  2025Q1      Not in labour force
# 592  Persons aged 15 years and over  2025Q1      Not in labour force
# 593  Persons aged 15 years and over  2025Q1      Not in labour force
# 594  Persons aged 15 years and over  2025Q1      Not in labour force
#
#                                            Nationality   value  period  \
# 0                                        All Countries  4056.3  2021Q1
# 1    EU14 excl Irl (countries in the EU pre 2004 ex...    80.9  2021Q1
# 2    EU15 to EU27 (accession countries joined post ...   207.1  2021Q1
# 3                                       United Kingdom    91.3  2021Q1
# 4                                              Ireland  3478.3  2021Q1
# ..                                                 ...     ...     ...
# 590  EU15 to EU27 (accession countries joined post ...    38.4  2025Q1
# 591                                     United Kingdom    34.1  2025Q1
# 592                                            Ireland  1358.5  2025Q1
# 593                    All countries excluding Ireland   157.9  2025Q1
# 594  All countries excluding Ireland,United Kingdom...    71.2  2025Q1
#
#           date
# 0   2021-01-01
# 1   2021-01-01
# 2   2021-01-01
# 3   2021-01-01
# 4   2021-01-01
# ..         ...
# 590 2025-01-01
# 591 2025-01-01
# 592 2025-01-01
# 593 2025-01-01
# 594 2025-01-01
#
# [595 rows x 7 columns]

# %%
q2_dataframes = [df_qlf34, df_qlf35, df_qlf47, df_qlf48]

# %%
# renaming the nationality and citizenship columns in data to merge them later
for df in q2_dataframes:
    if df is df_qlf34 or df is df_qlf35:
        df['Nationality'] = df['Nationality'].map(natio_dict)
    else:
        df['Nationality'] = df['Nationality'].map(citi_dict)

    df.drop(df[df['Nationality'].isnull()].index, inplace=True)
    df.reset_index(drop=True, inplace=True)



#df_qlf34['Nationality'] = df_qlf34['Nationality'].map(natio_dict)
#df_qlf35['Nationality'] = df_qlf35['Nationality'].map(natio_dict)
#df_qlf47['Nationality'] = df_qlf47['Nationality'].map(citi_dict)
#df_qlf48['Nationality'] = df_qlf48['Nationality'].map(citi_dict)

#df.drop(df[df['Nationality'].isnull()].index, inplace=True)
#df.reset_index(drop=True,
#                     inplace=True)
df_qlf34
# Out:
#                                          STATISTIC Quarter Nationality  \
# 0     Persons aged 15 years and over in Employment  1998Q1        EU14
# 1     Persons aged 15 years and over in Employment  1998Q1        EU14
# 2     Persons aged 15 years and over in Employment  1998Q1        EU14
# 3     Persons aged 15 years and over in Employment  1998Q1        EU14
# 4     Persons aged 15 years and over in Employment  1998Q1        EU14
# ...                                            ...     ...         ...
# 7355  Persons aged 15 years and over in Employment  2020Q4      Non-EU
# 7356  Persons aged 15 years and over in Employment  2020Q4      Non-EU
# 7357  Persons aged 15 years and over in Employment  2020Q4      Non-EU
# 7358  Persons aged 15 years and over in Employment  2020Q4      Non-EU
# 7359  Persons aged 15 years and over in Employment  2020Q4      Non-EU
#
#                              NACE Rev 2 Economic Sector  value  period  \
# 0                             All NACE economic sectors    7.0  1998Q1
# 1                 Agriculture, forestry and fishing (A)    NaN  1998Q1
# 2                                      Construction (F)    NaN  1998Q1
# 3     Wholesale and retail trade; repair of motor ve...    NaN  1998Q1
# 4                        Transportation and storage (H)    NaN  1998Q1
# ...                                                 ...    ...     ...
# 7355        Human health and social work activities (Q)   21.7  2020Q4
# 7356                                  Industry (B to E)    NaN  2020Q4
# 7357  Financial, insurance and real estate activitie...    NaN  2020Q4
# 7358                     Other NACE activities (R to U)    NaN  2020Q4
# 7359                                         Not stated    NaN  2020Q4
#
#            date
# 0    1998-01-01
# 1    1998-01-01
# 2    1998-01-01
# 3    1998-01-01
# 4    1998-01-01
# ...         ...
# 7355 2020-10-01
# 7356 2020-10-01
# 7357 2020-10-01
# 7358 2020-10-01
# 7359 2020-10-01
#
# [7360 rows x 7 columns]
